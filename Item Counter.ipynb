# %% [markdown]
# Item Counter

# %%
# Step 1: Mount Google Drive
from google.colab import drive
import os

drive.mount('/content/drive')

# Step 2: Set your folder path (relative to 'My Drive')
folder_path = '/content/drive/My Drive/Dataset/positive'

# Step 3: Count the number of items (files and folders) in the given path
items = os.listdir(folder_path)
count = len(items)

# Step 4: Print the result
print(f"Number of items in the folder: {count}")
# Out:
# Mounted at /content/drive
# Number of items in the folder: 4552
